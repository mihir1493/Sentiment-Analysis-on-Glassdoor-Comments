# %%
import pandas as pd

# %%
# Creating a dataframe to read the json file that includes the comments for each individual
df1 = pd.read_json('wells_final.json')

# %%
# Printing the dataframe
df1
# Out:
#                                                  rating  \
# 0     [5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 5.0, ...
# 1     [5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 5.0, ...
# 2     [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# 3     [4.0, 5.0, 4.0, 4.0, 4.0, 4.0, 4.0, 5.0, 4.0, ...
# 4     [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# ...                                                 ...
# 996   [4.0, 4.0, 4.0, 3.0, 3.0, 3.0, 3.0, 3.0, 5.0, ...
# 997   [2.0, 2.0, 4.0, 4.0, 4.0, 3.0, 5.0, 1.0, 4.0, ...
# 998   [5.0, 5.0, 4.0, 4.0, 5.0, 3.0, 3.0, 3.0, 5.0, ...
# 999   [2.0, 3.0, 5.0, 5.0, 2.0, 3.0, 3.0, 3.0, 3.0, ...
# 1000  [5.0, 2.0, 1.0, 1.0, 1.0, 5.0, 4.0, 4.0, 4.0, ...
#
#                                           employee_type  \
# 0     [Current Employee, more than 1 year, Current E...
# 1     [Current Employee, more than 1 year, Current E...
# 2     [Current Employee, Former Employee, Current Em...
# 3     [Former Employee, Former Employee, more than 5...
# 4     [Current Employee, Current Employee, less than...
# ...                                                 ...
# 996   [Current Employee, more than 3 years, Current ...
# 997   [Former Employee, less than 1 year, Current Em...
# 998   [Current Employee, more than 3 years, Current ...
# 999   [Former Employee, more than 8 years, Current E...
# 1000  [Current Employee, more than 1 year, Current E...
#
#                                                  review  \
# 0     [Great place for work & culture, Pros and some...
# 1     [Great place for work & culture, Pros and some...
# 2     [Working at Wellsfargo Auto, Teller review, Gr...
# 3     [Salary, Good place, Large organization with o...
# 4     [fast, awesome!, Good company, Wells Fargo, Gr...
# ...                                                 ...
# 996   [Great place to work at, Good starting pay, Yo...
# 997   [Sell your soul to open accounts, Meh, Good co...
# 998   [Advancement Opportunity, Great job, Teller, G...
# 999   [Behind the curtain is a real mess, Opportunit...
# 1000  [Great Company with Growth Opportunity, Factor...
#
#                                           date_position  \
# 0     [Nov 25, 2021 - Treasury Management Sales Anal...
# 1     [Nov 25, 2021 - Treasury Management Sales Anal...
# 2     [Nov 23, 2021 - Customer Support Specialist, N...
# 3     [Nov 23, 2021 - Anonymous Employee, Nov 21, 20...
# 4     [Nov 19, 2021 - Programmer Analyst, Nov 19, 20...
# ...                                                 ...
# 996   [May 21, 2019 - Bank Teller, May 21, 2019 - Te...
# 997   [Jun 4, 2019 - Bank Teller, Jun 4, 2019 - Anon...
# 998   [May 19, 2019 - Licensed Personal Banker, May ...
# 999   [May 31, 2019 - Change Consultant, May 31, 201...
# 1000  [May 14, 2019 - Lead Teller, May 28, 2019 - Bu...
#
#                                                    pros  \
# 0     [Great management\r\nPlenty of PTO\r\nTons of ...
# 1     [Great management\r\nPlenty of PTO\r\nTons of ...
# 2     [Working at wells fargo auto was a positive ex...
# 3     [Have good opportunities,you can switch betwee...
# 4     [the process was easy and fast, Amazing team, ...
# ...                                                 ...
# 996   [Flexible schedule.\r\nA lot of time off.\r\nG...
# 997   [-schedule is bank hours so night shifts or lo...
# 998   [Advancement opportunity, tuition reimbursemen...
# 999   [Good pay, decent health insurance, good paid ...
# 1000  [Great Benefits, Culture, and growth opportuni...
#
#                                                    cons
# 0     [Intense schedule sometimes due to turnover, T...
# 1     [Intense schedule sometimes due to turnover, T...
# 2     [Because I was a temporary employee, I had les...
# 3     [Management is not great,they will not show to...
# 4     [I dont have any cons, so complaints in my exp...
# ...                                                 ...
# 996   [Low pay compared with other banks, None yet a...
# 997   [-management expects you to get each and every...
# 998   [None that don’t exist in every company., Very...
# 999   [Lots of hidden politics and things hidden whe...
# 1000  [The sales goals of previous years hinder the ...
#
# [1001 rows x 6 columns]

# %%
# Using pandas explode() function to split the list in cell elements into individual row element across each column category
# Use Pandas >= 0.25 version
df1 = df1.apply(pd.Series.explode).reset_index()
df1.head()
# Out:
#    index rating                        employee_type  \
# 0      0    5.0   Current Employee, more than 1 year
# 1      0    4.0  Current Employee, more than 3 years
# 2      0    5.0                     Current Employee
# 3      0    5.0                      Former Employee
# 4      0    5.0                     Current Employee
#
#                            review  \
# 0  Great place for work & culture
# 1              Pros and some Cons
# 2        good working environment
# 3                   Great company
# 4                     Wells Fargo
#
#                                        date_position  \
# 0   Nov 25, 2021 - Treasury Management Sales Analyst
# 1  Nov 25, 2021 - Business Initiatives Consultant...
# 2                Nov 24, 2021 - Sales Representative
# 3                  Nov 24, 2021 - Compliance Manager
# 4                           Nov 24, 2021 - Recruiter
#
#                                                 pros  \
# 0  Great management\r\nPlenty of PTO\r\nTons of c...
# 1  Amazing Pay and Benefits, Great Accommodations...
# 2  Everyone is really friendly, work environment ...
# 3               great pay great hours great benefits
# 4              Good work life balance- paid time off
#
#                                                 cons
# 0         Intense schedule sometimes due to turnover
# 1  Training has been non-existent for many of us,...
# 2                           can get a bit repetitive
# 3        unfortunately laid off due to lack of funds
# 4  Too big , when you have an issue it can take d...

# %%
# Splitting the date_position colmun into two individual columns called "date" & "job title"
df1[['date','job title']] = df1['date_position'].str.split("-", n=1, expand=True)
df1.head()
# Out:
#    index rating                        employee_type  \
# 0      0    5.0   Current Employee, more than 1 year
# 1      0    4.0  Current Employee, more than 3 years
# 2      0    5.0                     Current Employee
# 3      0    5.0                      Former Employee
# 4      0    5.0                     Current Employee
#
#                            review  \
# 0  Great place for work & culture
# 1              Pros and some Cons
# 2        good working environment
# 3                   Great company
# 4                     Wells Fargo
#
#                                        date_position  \
# 0   Nov 25, 2021 - Treasury Management Sales Analyst
# 1  Nov 25, 2021 - Business Initiatives Consultant...
# 2                Nov 24, 2021 - Sales Representative
# 3                  Nov 24, 2021 - Compliance Manager
# 4                           Nov 24, 2021 - Recruiter
#
#                                                 pros  \
# 0  Great management\r\nPlenty of PTO\r\nTons of c...
# 1  Amazing Pay and Benefits, Great Accommodations...
# 2  Everyone is really friendly, work environment ...
# 3               great pay great hours great benefits
# 4              Good work life balance- paid time off
#
#                                                 cons           date  \
# 0         Intense schedule sometimes due to turnover  Nov 25, 2021
# 1  Training has been non-existent for many of us,...  Nov 25, 2021
# 2                           can get a bit repetitive  Nov 24, 2021
# 3        unfortunately laid off due to lack of funds  Nov 24, 2021
# 4  Too big , when you have an issue it can take d...  Nov 24, 2021
#
#                               job title
# 0     Treasury Management Sales Analyst
# 1   Business Initiatives Consultant III
# 2                  Sales Representative
# 3                    Compliance Manager
# 4                             Recruiter

# %%
# Checking the data type of each column using the .info() function
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          10001 non-null  int64
#  1   rating         10000 non-null  object
#  2   employee_type  10000 non-null  object
#  3   review         10000 non-null  object
#  4   date_position  10000 non-null  object
#  5   pros           10000 non-null  object
#  6   cons           10000 non-null  object
#  7   date           10000 non-null  object
#  8   job title      10000 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 703.3+ KB

# %%
# Converting the "date" column datatype from object to date format 
df1['date'] = pd.to_datetime(df1['date'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          10001 non-null  int64
#  1   rating         10000 non-null  object
#  2   employee_type  10000 non-null  object
#  3   review         10000 non-null  object
#  4   date_position  10000 non-null  object
#  5   pros           10000 non-null  object
#  6   cons           10000 non-null  object
#  7   date           10000 non-null  datetime64[ns]
#  8   job title      10000 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 703.3+ KB

# %%
# Printing dataframe
df1.head(10)
# Out:
#    index rating                        employee_type  \
# 0      0    5.0   Current Employee, more than 1 year
# 1      0    4.0  Current Employee, more than 3 years
# 2      0    5.0                     Current Employee
# 3      0    5.0                      Former Employee
# 4      0    5.0                     Current Employee
# 5      0    5.0   Former Employee, more than 3 years
# 6      0    4.0                      Former Employee
# 7      0    4.0                     Current Employee
# 8      0    5.0                      Former Employee
# 9      0    5.0    Former Employee, more than 1 year
#
#                            review  \
# 0  Great place for work & culture
# 1              Pros and some Cons
# 2        good working environment
# 3                   Great company
# 4                     Wells Fargo
# 5           Good Bank to work for
# 6                            good
# 7                       Good Team
# 8                      Teller Pay
# 9              good place to work
#
#                                        date_position  \
# 0   Nov 25, 2021 - Treasury Management Sales Analyst
# 1  Nov 25, 2021 - Business Initiatives Consultant...
# 2                Nov 24, 2021 - Sales Representative
# 3                  Nov 24, 2021 - Compliance Manager
# 4                           Nov 24, 2021 - Recruiter
# 5              Nov 24, 2021 - Lead Teller/Supervisor
# 6                         Nov 24, 2021 - Bank Teller
# 7                  Nov 25, 2021 - Anonymous Employee
# 8                              Nov 23, 2021 - Teller
# 9                     Nov 23, 2021 - Personal Banker
#
#                                                 pros  \
# 0  Great management\r\nPlenty of PTO\r\nTons of c...
# 1  Amazing Pay and Benefits, Great Accommodations...
# 2  Everyone is really friendly, work environment ...
# 3               great pay great hours great benefits
# 4              Good work life balance- paid time off
# 5           Customer Experience is the main priority
# 6             working with a lot of different people
# 7                       Great teammates to work with
# 8              Fair Pay, Good Vacation, Room to Grow
# 9      Good environment, all employees are friendly.
#
#                                                 cons       date  \
# 0         Intense schedule sometimes due to turnover 2021-11-25
# 1  Training has been non-existent for many of us,... 2021-11-25
# 2                           can get a bit repetitive 2021-11-24
# 3        unfortunately laid off due to lack of funds 2021-11-24
# 4  Too big , when you have an issue it can take d... 2021-11-24
# 5                 Hard to move up within the company 2021-11-24
# 6                 easy to get fired, if you mess up. 2021-11-24
# 7  Restrictions for trading of stocks and derivat... 2021-11-25
# 8                             Very busy all the time 2021-11-23
# 9                          have to meet Sales quotes 2021-11-23
#
#                               job title
# 0     Treasury Management Sales Analyst
# 1   Business Initiatives Consultant III
# 2                  Sales Representative
# 3                    Compliance Manager
# 4                             Recruiter
# 5                Lead Teller/Supervisor
# 6                           Bank Teller
# 7                    Anonymous Employee
# 8                                Teller
# 9                       Personal Banker

# %%
# Finding the number of unique element in the dataframe column
df1.nunique()
# Out:
# index            1001
# rating              5
# employee_type      14
# review           5977
# date_position    8554
# pros             9669
# cons             9750
# date              921
# job title        2069
# dtype: int64

# %%
df1.columns
# Out:
# Index(['index', 'rating', 'employee_type', 'review', 'date_position', 'pros',
#        'cons', 'date', 'job title'],
#       dtype='object')

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1.columns
# Out:
# Index(['index', 'rating', 'employee_type', 'review', 'date_position', 'pros',
#        'cons', 'date', 'job title'],
#       dtype='object')

# %%
# Droping "index" column from the dataframe
df1 = df1.drop(['index'], axis=1)
df1.head()
# Out:
#   rating                        employee_type                          review  \
# 0    5.0   Current Employee, more than 1 year  Great place for work & culture
# 1    4.0  Current Employee, more than 3 years              Pros and some Cons
# 2    5.0                     Current Employee        good working environment
# 3    5.0                      Former Employee                   Great company
# 4    5.0                     Current Employee                     Wells Fargo
#
#                                        date_position  \
# 0   Nov 25, 2021 - Treasury Management Sales Analyst
# 1  Nov 25, 2021 - Business Initiatives Consultant...
# 2                Nov 24, 2021 - Sales Representative
# 3                  Nov 24, 2021 - Compliance Manager
# 4                           Nov 24, 2021 - Recruiter
#
#                                                 pros  \
# 0  Great management\r\nPlenty of PTO\r\nTons of c...
# 1  Amazing Pay and Benefits, Great Accommodations...
# 2  Everyone is really friendly, work environment ...
# 3               great pay great hours great benefits
# 4              Good work life balance- paid time off
#
#                                                 cons       date  \
# 0         Intense schedule sometimes due to turnover 2021-11-25
# 1  Training has been non-existent for many of us,... 2021-11-25
# 2                           can get a bit repetitive 2021-11-24
# 3        unfortunately laid off due to lack of funds 2021-11-24
# 4  Too big , when you have an issue it can take d... 2021-11-24
#
#                               job title
# 0     Treasury Management Sales Analyst
# 1   Business Initiatives Consultant III
# 2                  Sales Representative
# 3                    Compliance Manager
# 4                             Recruiter

# %% [markdown]
# ## Data Consolidation

# %%
df1.dropna(inplace=True)

# %%
# Importing dataset using pd.read_csv

# %%
df1.head()
# Out:
#   rating                        employee_type                          review  \
# 0    5.0   Current Employee, more than 1 year  Great place for work & culture
# 1    4.0  Current Employee, more than 3 years              Pros and some Cons
# 2    5.0                     Current Employee        good working environment
# 3    5.0                      Former Employee                   Great company
# 4    5.0                     Current Employee                     Wells Fargo
#
#                                                 pros  \
# 0  Great management\r\nPlenty of PTO\r\nTons of c...
# 1  Amazing Pay and Benefits, Great Accommodations...
# 2  Everyone is really friendly, work environment ...
# 3               great pay great hours great benefits
# 4              Good work life balance- paid time off
#
#                                                 cons       date  \
# 0         Intense schedule sometimes due to turnover 2021-11-25
# 1  Training has been non-existent for many of us,... 2021-11-25
# 2                           can get a bit repetitive 2021-11-24
# 3        unfortunately laid off due to lack of funds 2021-11-24
# 4  Too big , when you have an issue it can take d... 2021-11-24
#
#                               job title
# 0     Treasury Management Sales Analyst
# 1   Business Initiatives Consultant III
# 2                  Sales Representative
# 3                    Compliance Manager
# 4                             Recruiter

# %%
# df1 = df1.drop(['date_position'], axis=1)
# df1.head()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 10000
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rating         10000 non-null  object
#  1   employee_type  10000 non-null  object
#  2   review         10000 non-null  object
#  3   pros           10000 non-null  object
#  4   cons           10000 non-null  object
#  5   date           10000 non-null  datetime64[ns]
#  6   job title      10000 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 625.0+ KB

# %%
df1.to_csv('wells_fargo_final.csv')
