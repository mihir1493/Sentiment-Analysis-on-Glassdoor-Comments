# %%
import pandas as pd

# %%
# Creating a dataframe to read the json file that includes the comments for each individual
df = pd.read_json('glassdoor/items.json')

# %%
# Printing the dataframe
df
# Out:
#                                               rating  \
# 0  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, ...
# 1  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, ...
# 2  [4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# 3  [4.0, 4.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# 4  [4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 5.0, ...
# 5  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
#
#                                        employee_type  \
# 0  [Current Employee, Former Employee, Current Em...
# 1  [Current Employee, Former Employee, Current Em...
# 2  [Current Employee, Current Employee, less than...
# 3  [Current Employee, more than 5 years, Current ...
# 4  [Former Employee, Former Employee, more than 1...
# 5  [Current Employee, Former Employee, less than ...
#
#                                               review  \
# 0  [Feet killer, Great benefits, Busy, Satisfied,...
# 1  [Feet killer, Great benefits, Busy, Satisfied,...
# 2  [Not a lot of room to grow., Yeah, A very good...
# 3  [It's what you make it, Walmart Employment, Jo...
# 4  [Cashier, Good Company, It's a good first job,...
# 5  [Good place to start., Great store, Great comp...
#
#                                        date_position  \
# 0  [Oct 16, 2021 - Order Filler, Oct 16, 2021 - P...
# 1  [Oct 16, 2021 - Order Filler, Oct 16, 2021 - P...
# 2  [Oct 16, 2021 - Pharmacy Technician, Oct 15, 2...
# 3  [Oct 15, 2021 - Sales Associate, Oct 15, 2021 ...
# 4  [Oct 14, 2021 - Anonymous Employee, Oct 14, 20...
# 5  [Oct 13, 2021 - Part Time Cashier, Oct 13, 202...
#
#                                                 pros  \
# 0  [Will loose weight very quickly, Hard work but...
# 1  [Will loose weight very quickly, Hard work but...
# 2  [Decent pay.\r\nGood hours,.\r\nFlexible sched...
# 3  [•Store culture\n•Good pay\n•Easy to move up i...
# 4  [Great people with flexible hours., Good compa...
# 5  [-Flexible hours\r\n-Good Benifits\r\n-Good Pa...
#
#                                                 cons
# 0  [Long hours varying schedule no AC, A lot of w...
# 1  [Long hours varying schedule no AC, A lot of w...
# 2  [No room to advance upwards., Bad management f...
# 3  [•Rude customers\n•Can be stressful\n•manageme...
# 4  [Disorganized departments. lack of communicati...
# 5  [-Perferred to work in 4 hour blocks\r\n-Custo...

# %%
# Using pandas explode() function to split the list in cell elements into individual row element across each column category
# Use Pandas >= 0.25 version
df3 = df.apply(pd.Series.explode).reset_index()
df3.head()
# Out:
#    index rating                       employee_type          review  \
# 0      0    5.0                    Current Employee     Feet killer
# 1      0    5.0                     Former Employee  Great benefits
# 2      0    5.0  Current Employee, more than 1 year            Busy
# 3      0    5.0                     Former Employee       Satisfied
# 4      0    5.0   Former Employee, more than 1 year     Good Option
#
#                      date_position  \
# 0      Oct 16, 2021 - Order Filler
# 1        Oct 16, 2021 - Pharmacist
# 2      Oct 16, 2021 - Area Manager
# 3   Oct 16, 2021 - Sales Associate
# 4  Oct 16, 2021 - Personal Shopper
#
#                                                 pros  \
# 0                     Will loose weight very quickly
# 1                       Hard work but great benefits
# 2               Pay benefits pay insurance employees
# 3                  Team work is valuable & respected
# 4  Flexibility, positive environment, constant ch...
#
#                                                 cons
# 0                  Long hours varying schedule no AC
# 1                    A lot of work with minimal time
# 2                       Lunch time clock brakes been
# 3               No set schedule, constantly changing
# 4  The work can sometimes get overwhelming when y...

# %%
# Splitting the date_position colmun into two individual columns called "date" & "job title"
df3[['date','job title']] = df3['date_position'].str.split("-", n=1, expand=True)
df3.head()
# Out:
#    index rating                       employee_type          review  \
# 0      0    5.0                    Current Employee     Feet killer
# 1      0    5.0                     Former Employee  Great benefits
# 2      0    5.0  Current Employee, more than 1 year            Busy
# 3      0    5.0                     Former Employee       Satisfied
# 4      0    5.0   Former Employee, more than 1 year     Good Option
#
#                      date_position  \
# 0      Oct 16, 2021 - Order Filler
# 1        Oct 16, 2021 - Pharmacist
# 2      Oct 16, 2021 - Area Manager
# 3   Oct 16, 2021 - Sales Associate
# 4  Oct 16, 2021 - Personal Shopper
#
#                                                 pros  \
# 0                     Will loose weight very quickly
# 1                       Hard work but great benefits
# 2               Pay benefits pay insurance employees
# 3                  Team work is valuable & respected
# 4  Flexibility, positive environment, constant ch...
#
#                                                 cons           date  \
# 0                  Long hours varying schedule no AC  Oct 16, 2021
# 1                    A lot of work with minimal time  Oct 16, 2021
# 2                       Lunch time clock brakes been  Oct 16, 2021
# 3               No set schedule, constantly changing  Oct 16, 2021
# 4  The work can sometimes get overwhelming when y...  Oct 16, 2021
#
#            job title
# 0       Order Filler
# 1         Pharmacist
# 2       Area Manager
# 3    Sales Associate
# 4   Personal Shopper

# %%
# Checking the data type of each column using the .info() function
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          60 non-null     int64
#  1   rating         60 non-null     object
#  2   employee_type  60 non-null     object
#  3   review         60 non-null     object
#  4   date_position  60 non-null     object
#  5   pros           60 non-null     object
#  6   cons           60 non-null     object
#  7   date           60 non-null     object
#  8   job title      60 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 4.3+ KB

# %%
# Converting the "date" column datatype from object to date format 
df3['date'] = pd.to_datetime(df3['date'])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          60 non-null     int64
#  1   rating         60 non-null     object
#  2   employee_type  60 non-null     object
#  3   review         60 non-null     object
#  4   date_position  60 non-null     object
#  5   pros           60 non-null     object
#  6   cons           60 non-null     object
#  7   date           60 non-null     datetime64[ns]
#  8   job title      60 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 4.3+ KB

# %%
# Printing dataframe
df3.head(10)
# Out:
#    index rating                       employee_type  \
# 0      0    5.0                    Current Employee
# 1      0    5.0                     Former Employee
# 2      0    5.0  Current Employee, more than 1 year
# 3      0    5.0                     Former Employee
# 4      0    5.0   Former Employee, more than 1 year
# 5      0    5.0                    Current Employee
# 6      0    5.0                    Current Employee
# 7      0    5.0  Former Employee, more than 8 years
# 8      0    4.0   Former Employee, less than 1 year
# 9      0    4.0                    Current Employee
#
#                                             review  \
# 0                                      Feet killer
# 1                                   Great benefits
# 2                                             Busy
# 3                                        Satisfied
# 4                                      Good Option
# 5                                              Pay
# 6                                    Great Company
# 7                                     Great People
# 8                               Walmart OGP Review
# 9  Good hours, pay, & benefits; stressful at times
#
#                                     date_position  \
# 0                     Oct 16, 2021 - Order Filler
# 1                       Oct 16, 2021 - Pharmacist
# 2                     Oct 16, 2021 - Area Manager
# 3                  Oct 16, 2021 - Sales Associate
# 4                 Oct 16, 2021 - Personal Shopper
# 5                Oct 16, 2021 - Overnight Stocker
# 6      Oct 16, 2021 - Walmart Warehouse Associate
# 7                          Oct 16, 2021 - Plumber
# 8  Oct 16, 2021 - Online Grocery Pickup Associate
# 9                 Oct 16, 2021 - Personal Shopper
#
#                                                 pros  \
# 0                     Will loose weight very quickly
# 1                       Hard work but great benefits
# 2               Pay benefits pay insurance employees
# 3                  Team work is valuable & respected
# 4  Flexibility, positive environment, constant ch...
# 5                       Decent pay super nice people
# 6               They care about you! Great benefits!
# 7                Greaty Pay Great Hours Great Owners
# 8  The pay was good for a summer job. The coworke...
# 9  Decent pay; good hours & benefits; room to gro...
#
#                                                 cons           date  \
# 0                  Long hours varying schedule no AC  Oct 16, 2021
# 1                    A lot of work with minimal time  Oct 16, 2021
# 2                       Lunch time clock brakes been  Oct 16, 2021
# 3               No set schedule, constantly changing  Oct 16, 2021
# 4  The work can sometimes get overwhelming when y...  Oct 16, 2021
# 5                         The point system sucks lol  Oct 16, 2021
# 6   Mandatory overtime, special during the holidays.  Oct 16, 2021
# 7                                   No cons at all !  Oct 16, 2021
# 8  There were at times when people would call out...  Oct 16, 2021
# 9  Stressful at times; customers can be difficult...  Oct 16, 2021
#
#                           job title
# 0                      Order Filler
# 1                        Pharmacist
# 2                      Area Manager
# 3                   Sales Associate
# 4                  Personal Shopper
# 5                 Overnight Stocker
# 6       Walmart Warehouse Associate
# 7                           Plumber
# 8   Online Grocery Pickup Associate
# 9                  Personal Shopper

# %%
# Finding the number of unique element in the dataframe column
df3.nunique()
# Out:
# index             6
# rating            2
# employee_type    10
# review           46
# date_position    42
# pros             49
# cons             49
# date              4
# job title        37
# dtype: int64

# %%
df3.columns
# Out:
# Index(['index', 'rating', 'employee_type', 'review', 'date_position', 'pros',
#        'cons', 'date', 'job title'],
#       dtype='object')

# %%
df3.reset_index(drop=True, inplace=True)

# %%
# Droping "index" column from the dataframe
df3.drop(['index'], axis=1)
df3.head()
# Out:
#    index rating                       employee_type          review  \
# 0      0    5.0                    Current Employee     Feet killer
# 1      0    5.0                     Former Employee  Great benefits
# 2      0    5.0  Current Employee, more than 1 year            Busy
# 3      0    5.0                     Former Employee       Satisfied
# 4      0    5.0   Former Employee, more than 1 year     Good Option
#
#                      date_position  \
# 0      Oct 16, 2021 - Order Filler
# 1        Oct 16, 2021 - Pharmacist
# 2      Oct 16, 2021 - Area Manager
# 3   Oct 16, 2021 - Sales Associate
# 4  Oct 16, 2021 - Personal Shopper
#
#                                                 pros  \
# 0                     Will loose weight very quickly
# 1                       Hard work but great benefits
# 2               Pay benefits pay insurance employees
# 3                  Team work is valuable & respected
# 4  Flexibility, positive environment, constant ch...
#
#                                                 cons           date  \
# 0                  Long hours varying schedule no AC  Oct 16, 2021
# 1                    A lot of work with minimal time  Oct 16, 2021
# 2                       Lunch time clock brakes been  Oct 16, 2021
# 3               No set schedule, constantly changing  Oct 16, 2021
# 4  The work can sometimes get overwhelming when y...  Oct 16, 2021
#
#            job title
# 0       Order Filler
# 1         Pharmacist
# 2       Area Manager
# 3    Sales Associate
# 4   Personal Shopper

# %%
# Exporting cleaned data as csv
df3.to_csv('cleaned_data.csv')
