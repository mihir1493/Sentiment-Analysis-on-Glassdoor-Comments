# %%
import pandas as pd

# %%
# Creating a dataframe to read the json file that includes the comments for each individual
df1 = pd.read_json('walmart_final.json')

# %%
# Printing the dataframe
df1
# Out:
#                                                  rating  \
# 0     [5.0, 5.0, 5.0, 2.0, 4.0, 2.0, 1.0, 3.0, 4.0, ...
# 1     [5.0, 5.0, 5.0, 2.0, 4.0, 2.0, 1.0, 3.0, 4.0, ...
# 2     [4.0, 5.0, 2.0, 4.0, 2.0, 1.0, 5.0, 3.0, 2.0, ...
# 3     [4.0, 5.0, 5.0, 3.0, 4.0, 4.0, 5.0, 3.0, 4.0, ...
# 4     [3.0, 4.0, 2.0, 5.0, 4.0, 1.0, 4.0, 2.0, 4.0, ...
# ...                                                 ...
# 996   [4.0, 1.0, 2.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, ...
# 997   [3.0, 5.0, 4.0, 5.0, 5.0, 4.0, 3.0, 1.0, 3.0, ...
# 998   [3.0, 4.0, 4.0, 5.0, 4.0, 3.0, 3.0, 1.0, 5.0, ...
# 999   [3.0, 3.0, 1.0, 3.0, 3.0, 1.0, 3.0, 3.0, 2.0, ...
# 1000  [4.0, 3.0, 2.0, 4.0, 5.0, 4.0, 4.0, 3.0, 4.0, ...
#
#                                           employee_type  \
# 0     [Former Employee, Former Employee, less than 1...
# 1     [Former Employee, Former Employee, less than 1...
# 2     [Current Employee, more than 3 years, Former E...
# 3     [Current Employee, less than 1 year, Former Em...
# 4     [Current Employee, Current Employee, Former Em...
# ...                                                 ...
# 996   [Former Employee, more than 1 year, Current Em...
# 997   [Former Employee, less than 1 year, Former Emp...
# 998   [Current Employee, Current Employee, less than...
# 999   [Current Employee, less than 1 year, Former Em...
# 1000  [Former Employee, less than 1 year, Former Emp...
#
#                                                  review  \
# 0     [So much good like, From an Asst Store Manager...
# 1     [So much good like, From an Asst Store Manager...
# 2     [Free Schooling, Decent part time job!, Not th...
# 3     [Decent job if you have good supervisors, Grea...
# 4     [Pretty okay, Decent Job, Undervalued and Unde...
# ...                                                 ...
# 996   [Good place to work, It’s Eh, If you are color...
# 997   [Okay, Amazing, Its fine, Y, Flexible, pretty ...
# 998   [Waiting on a salary increase, OrderFiller, It...
# 999   [Working at Walmart, Typical retail experience...
# 1000  [It was good, Not bad for a college job, Start...
#
#                                           date_position  \
# 0     [Oct 12, 2021 - Cashier, Jun 2, 2015 - Assista...
# 1     [Oct 12, 2021 - Cashier, Jun 2, 2015 - Assista...
# 2     [Nov 25, 2021 - CAP2 Associate, Nov 27, 2021 -...
# 3     [Nov 6, 2021 - Apparel Team Member, Nov 21, 20...
# 4     [Nov 23, 2021 - Online Shopper, Nov 26, 2021 -...
# ...                                                 ...
# 996   [Apr 13, 2021 - Personal Shopper, Jul 25, 2021...
# 997   [Jun 5, 2021 - Online Grocery Pickup, Apr 9, 2...
# 998   [Apr 22, 2021 - Asset Protection Customer Host...
# 999   [Jun 17, 2021 - Apparel Associate, Jun 20, 202...
# 1000  [Mar 31, 2021 - Front End Cashier, May 31, 202...
#
#                                                    pros  \
# 0     [Nice people for work with, Advancement opport...
# 1     [Nice people for work with, Advancement opport...
# 2     [Able to meet some interesting characters.\nFr...
# 3     [Walmart pays better than a lot of retail jobs...
# 4     [As long as you got some friends and a decent ...
# ...                                                 ...
# 996   [Friendly coworkers, easy work, great benefits...
# 997   [The schedule was pretty flexible, Good benefi...
# 998   [Customer Host is a good and easy job., Pay\r\...
# 999   [You get two fifteen minute breaks and an hour...
# 1000  [You get to see a lot of people and the money ...
#
#                                                    cons
# 0     [Not many monies left for wife, Understaffing ...
# 1     [Not many monies left for wife, Understaffing ...
# 2     [Leadership can be difficult to work for at ti...
# 3     [Making the apparel section not a mess every d...
# 4     [If anything, just make sure you have a lot of...
# ...                                                 ...
# 996   [Not the best system, frequently had troubles ...
# 997   [I was fired for excessive absence when they h...
# 998   [The customer host are managed well.\r\nIf the...
# 999   [You are on your feet all day, All of the cons...
# 1000  [Making sure u get there on time, Management s...
#
# [1001 rows x 6 columns]

# %%
# Using pandas explode() function to split the list in cell elements into individual row element across each column category
# Use Pandas >= 0.25 version
df1 = df1.apply(pd.Series.explode).reset_index()
df1.head()
# Out:
#    index rating                         employee_type  \
# 0      0    5.0                       Former Employee
# 1      0    5.0     Former Employee, less than 1 year
# 2      0    5.0  Current Employee, more than 10 years
# 3      0    2.0                       Former Employee
# 4      0    4.0   Current Employee, more than 5 years
#
#                                          review  \
# 0                             So much good like
# 1                    From an Asst Store Manager
# 2        Big enough to get lost or hide out in.
# 3                 served my time in Wally World
# 4  Change is the only constant thing at Walmart
#
#                                    date_position  \
# 0                         Oct 12, 2021 - Cashier
# 1          Jun 2, 2015 - Assistant Store Manager
# 2  Nov 11, 2021 - Senior Staff Software Engineer
# 3                  Nov 26, 2021 - Nunya Business
# 4                         Nov 3, 2021 - Director
#
#                                                 pros  \
# 0                          Nice people for work with
# 1  Advancement opportunities, great at developing...
# 2  Size and scope of the enterprise means that wh...
# 3  Your typical soulless grind to earn Walmart an...
# 4  Endless opportunities for growth and promotion...
#
#                                                 cons
# 0                      Not many monies left for wife
# 1  Understaffing issues negatively affects all pa...
# 2  It's a retailer not an IT company. It's got th...
# 3       Start of shift and the dawn of the next day.
# 4  Different orgs have different priorities and m...

# %%
# Splitting the date_position colmun into two individual columns called "date" & "job title"
df1[['date','job title']] = df1['date_position'].str.split("-", n=1, expand=True)

df1.head()
# Out:
#    index rating                         employee_type  \
# 0      0    5.0                       Former Employee
# 1      0    5.0     Former Employee, less than 1 year
# 2      0    5.0  Current Employee, more than 10 years
# 3      0    2.0                       Former Employee
# 4      0    4.0   Current Employee, more than 5 years
#
#                                          review  \
# 0                             So much good like
# 1                    From an Asst Store Manager
# 2        Big enough to get lost or hide out in.
# 3                 served my time in Wally World
# 4  Change is the only constant thing at Walmart
#
#                                    date_position  \
# 0                         Oct 12, 2021 - Cashier
# 1          Jun 2, 2015 - Assistant Store Manager
# 2  Nov 11, 2021 - Senior Staff Software Engineer
# 3                  Nov 26, 2021 - Nunya Business
# 4                         Nov 3, 2021 - Director
#
#                                                 pros  \
# 0                          Nice people for work with
# 1  Advancement opportunities, great at developing...
# 2  Size and scope of the enterprise means that wh...
# 3  Your typical soulless grind to earn Walmart an...
# 4  Endless opportunities for growth and promotion...
#
#                                                 cons           date  \
# 0                      Not many monies left for wife  Oct 12, 2021
# 1  Understaffing issues negatively affects all pa...   Jun 2, 2015
# 2  It's a retailer not an IT company. It's got th...  Nov 11, 2021
# 3       Start of shift and the dawn of the next day.  Nov 26, 2021
# 4  Different orgs have different priorities and m...   Nov 3, 2021
#
#                          job title
# 0                          Cashier
# 1          Assistant Store Manager
# 2   Senior Staff Software Engineer
# 3                   Nunya Business
# 4                         Director

# %%
# Checking the data type of each column using the .info() function
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9974 entries, 0 to 9973
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          9974 non-null   int64
#  1   rating         9970 non-null   object
#  2   employee_type  9970 non-null   object
#  3   review         9970 non-null   object
#  4   date_position  9970 non-null   object
#  5   pros           9970 non-null   object
#  6   cons           9970 non-null   object
#  7   date           9970 non-null   object
#  8   job title      9970 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 701.4+ KB

# %%
# Converting the "date" column datatype from object to date format 
df1['date'] = pd.to_datetime(df1['date'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9974 entries, 0 to 9973
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          9974 non-null   int64
#  1   rating         9970 non-null   object
#  2   employee_type  9970 non-null   object
#  3   review         9970 non-null   object
#  4   date_position  9970 non-null   object
#  5   pros           9970 non-null   object
#  6   cons           9970 non-null   object
#  7   date           9970 non-null   datetime64[ns]
#  8   job title      9970 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 701.4+ KB

# %%
# Printing dataframe
df1.head(10)
# Out:
#    index rating                         employee_type  \
# 0      0    5.0                       Former Employee
# 1      0    5.0     Former Employee, less than 1 year
# 2      0    5.0  Current Employee, more than 10 years
# 3      0    2.0                       Former Employee
# 4      0    4.0   Current Employee, more than 5 years
# 5      0    2.0                      Current Employee
# 6      0    1.0     Former Employee, more than 1 year
# 7      0    3.0     Former Employee, less than 1 year
# 8      0    4.0    Current Employee, less than 1 year
# 9      0    4.0     Former Employee, more than 1 year
#
#                                          review  \
# 0                             So much good like
# 1                    From an Asst Store Manager
# 2        Big enough to get lost or hide out in.
# 3                 served my time in Wally World
# 4  Change is the only constant thing at Walmart
# 5                         Could be a lot better
# 6       Wal-Mart universe upside down backwards
# 7                                 Turnover high
# 8                         Better then expected.
# 9                                         great
#
#                                        date_position  \
# 0                             Oct 12, 2021 - Cashier
# 1              Jun 2, 2015 - Assistant Store Manager
# 2      Nov 11, 2021 - Senior Staff Software Engineer
# 3                      Nov 26, 2021 - Nunya Business
# 4                             Nov 3, 2021 - Director
# 5  Nov 7, 2021 - Electronics and Entertainment Te...
# 6                             Nov 25, 2021 - Stocker
# 7                     Nov 21, 2021 - Grocery Stocker
# 8           Nov 6, 2021 - Asset Protection Associate
# 9     Nov 26, 2021 - Customer Service Representative
#
#                                                 pros  \
# 0                          Nice people for work with
# 1  Advancement opportunities, great at developing...
# 2  Size and scope of the enterprise means that wh...
# 3  Your typical soulless grind to earn Walmart an...
# 4  Endless opportunities for growth and promotion...
# 5  There’s job security in the sense that retail ...
# 6  Not working hard gets you rewarded. Training i...
# 7  I’ll be forever grateful they hire people over...
# 8  *Reasonable Current Management\n*Friendly but ...
# 9  I enjoy using the mass email blast to remind m...
#
#                                                 cons       date  \
# 0                      Not many monies left for wife 2021-10-12
# 1  Understaffing issues negatively affects all pa... 2015-06-02
# 2  It's a retailer not an IT company. It's got th... 2021-11-11
# 3       Start of shift and the dawn of the next day. 2021-11-26
# 4  Different orgs have different priorities and m... 2021-11-03
# 5  Pay is static through positions middle managem... 2021-11-07
# 6  All ways do what they tell you or get voted of... 2021-11-25
# 7  Other than that, it could be a nightmare. The ... 2021-11-21
# 8  Extremely rude, unreasonable, and hostile cust... 2021-11-06
# 9  When an appointment is upcharged during servic... 2021-11-26
#
#                                   job title
# 0                                   Cashier
# 1                   Assistant Store Manager
# 2            Senior Staff Software Engineer
# 3                            Nunya Business
# 4                                  Director
# 5   Electronics and Entertainment Team Lead
# 6                                   Stocker
# 7                           Grocery Stocker
# 8                Asset Protection Associate
# 9           Customer Service Representative

# %%
# Finding the number of unique element in the dataframe column
df1.nunique()
# Out:
# index            1001
# rating              5
# employee_type      14
# review           5482
# date_position    7329
# pros             9472
# cons             9508
# date              334
# job title        1688
# dtype: int64

# %%
df1.columns
# Out:
# Index(['index', 'rating', 'employee_type', 'review', 'date_position', 'pros',
#        'cons', 'date', 'job title'],
#       dtype='object')

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1.columns
# Out:
# Index(['index', 'rating', 'employee_type', 'review', 'date_position', 'pros',
#        'cons', 'date', 'job title'],
#       dtype='object')

# %%
# Droping "index" column from the dataframe
df1 = df1.drop(['index'], axis=1)
df1.head()
# Out:
#   rating                         employee_type  \
# 0    5.0                       Former Employee
# 1    5.0     Former Employee, less than 1 year
# 2    5.0  Current Employee, more than 10 years
# 3    2.0                       Former Employee
# 4    4.0   Current Employee, more than 5 years
#
#                                          review  \
# 0                             So much good like
# 1                    From an Asst Store Manager
# 2        Big enough to get lost or hide out in.
# 3                 served my time in Wally World
# 4  Change is the only constant thing at Walmart
#
#                                    date_position  \
# 0                         Oct 12, 2021 - Cashier
# 1          Jun 2, 2015 - Assistant Store Manager
# 2  Nov 11, 2021 - Senior Staff Software Engineer
# 3                  Nov 26, 2021 - Nunya Business
# 4                         Nov 3, 2021 - Director
#
#                                                 pros  \
# 0                          Nice people for work with
# 1  Advancement opportunities, great at developing...
# 2  Size and scope of the enterprise means that wh...
# 3  Your typical soulless grind to earn Walmart an...
# 4  Endless opportunities for growth and promotion...
#
#                                                 cons       date  \
# 0                      Not many monies left for wife 2021-10-12
# 1  Understaffing issues negatively affects all pa... 2015-06-02
# 2  It's a retailer not an IT company. It's got th... 2021-11-11
# 3       Start of shift and the dawn of the next day. 2021-11-26
# 4  Different orgs have different priorities and m... 2021-11-03
#
#                          job title
# 0                          Cashier
# 1          Assistant Store Manager
# 2   Senior Staff Software Engineer
# 3                   Nunya Business
# 4                         Director

# %% [markdown]
# ## Data Consolidation

# %%
# Combining the dataset using concat function

# %%
df1.dropna(inplace=True)

# %%
# Importing dataset using pd.read_csv

# %%
df1.head()
# Out:
#   rating                         employee_type  \
# 0    5.0                       Former Employee
# 1    5.0     Former Employee, less than 1 year
# 2    5.0  Current Employee, more than 10 years
# 3    2.0                       Former Employee
# 4    4.0   Current Employee, more than 5 years
#
#                                          review  \
# 0                             So much good like
# 1                    From an Asst Store Manager
# 2        Big enough to get lost or hide out in.
# 3                 served my time in Wally World
# 4  Change is the only constant thing at Walmart
#
#                                    date_position  \
# 0                         Oct 12, 2021 - Cashier
# 1          Jun 2, 2015 - Assistant Store Manager
# 2  Nov 11, 2021 - Senior Staff Software Engineer
# 3                  Nov 26, 2021 - Nunya Business
# 4                         Nov 3, 2021 - Director
#
#                                                 pros  \
# 0                          Nice people for work with
# 1  Advancement opportunities, great at developing...
# 2  Size and scope of the enterprise means that wh...
# 3  Your typical soulless grind to earn Walmart an...
# 4  Endless opportunities for growth and promotion...
#
#                                                 cons       date  \
# 0                      Not many monies left for wife 2021-10-12
# 1  Understaffing issues negatively affects all pa... 2015-06-02
# 2  It's a retailer not an IT company. It's got th... 2021-11-11
# 3       Start of shift and the dawn of the next day. 2021-11-26
# 4  Different orgs have different priorities and m... 2021-11-03
#
#                          job title
# 0                          Cashier
# 1          Assistant Store Manager
# 2   Senior Staff Software Engineer
# 3                   Nunya Business
# 4                         Director

# %%
df1 = df1.drop(['date_position'], axis=1)
df1.head()
# Out:
#   rating                         employee_type  \
# 0    5.0                       Former Employee
# 1    5.0     Former Employee, less than 1 year
# 2    5.0  Current Employee, more than 10 years
# 3    2.0                       Former Employee
# 4    4.0   Current Employee, more than 5 years
#
#                                          review  \
# 0                             So much good like
# 1                    From an Asst Store Manager
# 2        Big enough to get lost or hide out in.
# 3                 served my time in Wally World
# 4  Change is the only constant thing at Walmart
#
#                                                 pros  \
# 0                          Nice people for work with
# 1  Advancement opportunities, great at developing...
# 2  Size and scope of the enterprise means that wh...
# 3  Your typical soulless grind to earn Walmart an...
# 4  Endless opportunities for growth and promotion...
#
#                                                 cons       date  \
# 0                      Not many monies left for wife 2021-10-12
# 1  Understaffing issues negatively affects all pa... 2015-06-02
# 2  It's a retailer not an IT company. It's got th... 2021-11-11
# 3       Start of shift and the dawn of the next day. 2021-11-26
# 4  Different orgs have different priorities and m... 2021-11-03
#
#                          job title
# 0                          Cashier
# 1          Assistant Store Manager
# 2   Senior Staff Software Engineer
# 3                   Nunya Business
# 4                         Director

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9970 entries, 0 to 9973
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rating         9970 non-null   object
#  1   employee_type  9970 non-null   object
#  2   review         9970 non-null   object
#  3   pros           9970 non-null   object
#  4   cons           9970 non-null   object
#  5   date           9970 non-null   datetime64[ns]
#  6   job title      9970 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 623.1+ KB

# %%
df1.to_csv('walmart_final.csv')
